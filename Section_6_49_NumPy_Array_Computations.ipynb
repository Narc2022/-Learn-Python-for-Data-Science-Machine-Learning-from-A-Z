# %% [markdown]
# <a href="https://colab.research.google.com/github/Narc2022/-Learn-Python-for-Data-Science-Machine-Learning-from-A-Z/blob/main/Section_6_49_NumPy_Array_Computations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Computation on Numpy;

# %% [markdown]
# #Vectorized Operations vs Loops
#
#
# *   Python loops slower
# *   Performance operations on large arrays becomes costly.
# *   Numpy provide an vectorized approach using Ufuncs
# *   Faster execution.
#
# ![Screenshot 2023-04-23 at 5.30.24 PM.png](data:image/png;base64,...)

# %%
import numpy as np
x = np.arange(4)

print("x = ",x)
print("x + 5 = ",x + 5)
print("x - 5 = ",x - 5)
print("x * 5 = ",x * 5)
# Out:
# x =  [0 1 2 3]
# x + 5 =  [5 6 7 8]
# x - 5 =  [-5 -4 -3 -2]
# x * 5 =  [ 0  5 10 15]

# %% [markdown]
# ![Screenshot 2023-04-23 at 5.33.21 PM.png](data:image/png;base64,...)
#
# ![Screenshot 2023-04-23 at 5.37.45 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![numpy-arrays-have-axes_updated_v2.webp](data:image/webp;base64,...)
